# %%
import os
import cv2
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
train_path = "../classification/Training"
classes = os.listdir(train_path)
for i, cls in enumerate(classes):
    img_name = os.listdir(os.path.join(train_path, cls))[0]
    img_path = os.path.join(train_path, cls, img_name)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(1, 4, i + 1)
    plt.imshow(img)
    plt.title(cls)
    plt.axis('off')
plt.show()

# %%
import os
formats = set()
train_path = "../classification/Training"
classes = os.listdir(train_path)
for cls in classes:
    cls_path = os.path.join(train_path, cls)
    for img in os.listdir(cls_path):
        formats.add(img.split('.')[-1])
print("Image formats found:", formats)
# Out:
# Image formats found: {'jpg'}

# %%
import os
import cv2
import random
train_path = "../classification/Training"
classes = os.listdir(train_path)
sample_class = random.choice(classes)
sample_image = random.choice(os.listdir(os.path.join(train_path, sample_class)))
img_path = os.path.join(train_path, sample_class, sample_image)
img = cv2.imread(img_path)
print("Image shape (H, W, C):", img.shape)
# Out:
# Image shape (H, W, C): (512, 512, 3)

# %%
import os
train_path = "../classification/Training"
classes = os.listdir(train_path)
for cls in classes:
    cls_path = os.path.join(train_path, cls)
    print(f"{cls}: {len(os.listdir(cls_path))} images")
# Out:
# glioma_tumor: 826 images
# meningioma_tumor: 822 images
# no_tumor: 395 images
# pituitary_tumor: 827 images
